# %%
import scipy as sc
import numpy as np
import matplotlib.pyplot as plt
import pyccl as ccl

# %%
def alpha_t_plus_GW(aM,A):
    root = (100*aM**2 - 400*aM + 400)*A**4 - 180*aM*A**2 + 360*aM +81
    nom = (10*aM+20)*A**2 - (20*aM + 9) + np.sqrt(root)
    denom = 40*(2*A**4 -(2+aM)*A**2 + aM)
    return nom / denom

def alpha_t_minus_GW(aM,A):
    root = (100*aM**2 - 400*aM + 400)*A**4 - 180*aM*A**2 + 360*aM +81
    nom = (10*aM+20)*A**2 - (20*aM + 9) - np.sqrt(root)
    denom = 40*(2*A**4 -(2+aM)*A**2 + aM)
    return nom / denom

def

# %%
alpha_M = 0

A = np.linspace(-10,10,int(1e2))

plt.plot(A, alpha_t_plus_GW(alpha_M,A))
plt.plot(A, alpha_t_minus_GW(alpha_M,A))
plt.plot(A,np.zeros(len(A)), "--k")
plt.ylim(-0.05,0.05)
# Out:
# (-0.05, 0.05)
